# %%
screen = [[0 for _ in range(1900)] for _ in range(1200)]

# %%
import numpy as np

# Constants
SCREEN_WIDTH = 1900
SCREEN_HEIGHT = 1200
STREET_WIDTH = 10  # Uniform width of the street

# Create an empty screen (0 for no color, 1 for street)
screen = np.zeros((SCREEN_HEIGHT, SCREEN_WIDTH), dtype=int)

# Function to draw a street using Bézier curves
def draw_street(screen, points, street_width, color=1):
    # Using points as control points for a smooth curve
    for t in np.linspace(0, 1, 500):
        x = int((1 - t)**2 * points[0][0] + 2 * (1 - t) * t * points[1][0] + t**2 * points[2][0])
        y = int((1 - t)**2 * points[0][1] + 2 * (1 - t) * t * points[1][1] + t**2 * points[2][1])
#         print("x ",x,"y ",y)
        # Draw the street by coloring the screen matrix
        for i in range(-street_width // 2, street_width // 2):
            for j in range(-street_width // 2, street_width // 2):
                if 0 <= x + i < SCREEN_WIDTH and 0 <= y + j < SCREEN_HEIGHT:
                    screen[y + j][x + i] = color
    

# Example points for Bézier curve (start, control, end points)
points = [(100, 100), (400, 500), (100, 1000)]

# Draw the street on the screen
draw_street(screen, points, STREET_WIDTH)

# %%
import matplotlib.pyplot as plt

# פונקציה להצגת המסך
def display_screen(screen):
    plt.imshow(screen, cmap='gray')
    plt.show()

# קריאה לפונקציה להצגת המסך
display_screen(screen)

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# Constants
SCREEN_WIDTH = 1900
SCREEN_HEIGHT = 1200
STREET_WIDTH = 10  # Uniform width of the street
NUM_STREETS = 5

# Create an empty screen (0 for no color, 1 for street)
screen = np.zeros((SCREEN_HEIGHT, SCREEN_WIDTH), dtype=int)

# Function to draw a street using Bézier curves
def draw_street(screen, points, street_width, color=1):
    for t in np.linspace(0, 1, 500):
        x = int((1 - t)**2 * points[0][0] + 2 * (1 - t) * t * points[1][0] + t**2 * points[2][0])
        y = int((1 - t)**2 * points[0][1] + 2 * (1 - t) * t * points[1][1] + t**2 * points[2][1])
        for i in range(-street_width // 2, street_width // 2):
            for j in range(-street_width // 2, street_width // 2):
                if 0 <= x + i < SCREEN_WIDTH and 0 <= y + j < SCREEN_HEIGHT:
                    screen[y + j][x + i] = color

# Function to generate random connected streets
def generate_random_connected_streets(screen, num_streets, street_width):
    # Start at a random point on the screen
    start_x = random.randint(100, SCREEN_WIDTH - 100)
    start_y = random.randint(100, SCREEN_HEIGHT - 100)
    
    for _ in range(num_streets):
        # Randomly choose the next control point and end point
        control_x = random.randint(max(0, start_x - 200), min(SCREEN_WIDTH, start_x + 200))
        control_y = random.randint(max(0, start_y - 200), min(SCREEN_HEIGHT, start_y + 200))
        
        end_x = random.randint(max(0, control_x - 200), min(SCREEN_WIDTH, control_x + 200))
        end_y = random.randint(max(0, control_y - 200), min(SCREEN_HEIGHT, control_y + 200))
        
        # Define points for the Bézier curve (start, control, end)
        points = [(start_x, start_y), (control_x, control_y), (end_x, end_y)]
        
        # Draw the street
        draw_street(screen, points, street_width)
        
        # The next street starts where the previous one ended
        start_x, start_y = end_x, end_y

# Function to display the screen
def display_screen(screen):
    plt.imshow(screen, cmap='gray')
    plt.show()

# Generate and display 5 connected streets
generate_random_connected_streets(screen, NUM_STREETS, STREET_WIDTH)
display_screen(screen)

# %%
class Street:
    def __init__(self,points):
        self.points = points
        
    def random_point():
        pass

# %%
import numpy as np

# Constants
SCREEN_WIDTH = 1900
SCREEN_HEIGHT = 1200
STREET_WIDTH = 15  # Uniform width of the street

# Create an empty screen (0 for no color, 1 for street)
screen = np.zeros((SCREEN_HEIGHT, SCREEN_WIDTH), dtype=int)

# Function to draw a street using Bézier curves
def draw_street(screen, points, street_width, color=1):
    # Using points as control points for a smooth curve
    s = []
    for t in np.linspace(0, 1, 500):
        x = int((1 - t)**2 * points[0][0] + 2 * (1 - t) * t * points[1][0] + t**2 * points[2][0])
        y = int((1 - t)**2 * points[0][1] + 2 * (1 - t) * t * points[1][1] + t**2 * points[2][1])
#         print("x ",x,"y ",y)
        # Draw the street by coloring the screen matrix
        for i in range(-street_width // 2, street_width // 2):
            for j in range(-street_width // 2, street_width // 2):
                if 0 <= x + i < SCREEN_WIDTH and 0 <= y + j < SCREEN_HEIGHT:
                    screen[y + j][x + i] = color
        s.append([x,y])
    return Street(s)
    

# Example points for Bézier curve (start, control, end points)
points = [(200, 200), (400, 800), (1200, 1000)]

# Draw the street on the screen
draw_street(screen, points, STREET_WIDTH)
import matplotlib.pyplot as plt

# פונקציה להצגת המסך
def display_screen(screen):
    plt.imshow(screen, cmap='gray')
    plt.show()

# קריאה לפונקציה להצגת המסך
display_screen(screen)

# %%
import statistics

class Building:
    dist=5
    data={
        'Big':{
            'Height':[50,10],
            'Width':[30,5],
            'Depth':[25,4]
        },
        'Mean':{
            'Height':[30,8],
            'Width':[20,4],
            'Depth':[15,3]
        },
        'Small':{
            'Height':[15,5],
            'Width':[10,2],
            'Depth':[8,2]
        }
    }
    def __init__(self, street, city, street_size='Mean'):
        
        
        height = random.gauss(self.data[street_size]['Height'][0],self.data[street_size]['Height'][1])
        width = random.gauss(self.data[street_size]['Width'][0],self.data[street_size]['Width'][1])
        depth = random.gauss(self.data[street_size]['Depth'][0],self.data[street_size]['Depth'][1])
        
        self.size = [height,width,depth]
        
        print("*",width," ", [street.points[0][0],street.points[0][1]])
        
        self.point= self.find_point(city, width, [street.points[0][0],street.points[0][1]])
        self.location = 0
        
    def find_point(self, screen, width, point):
        print('wid', width)
        a = point[0]
        b = point[1]
        r = int(width)
        street_width=15
        x_lst=[]
        y_lst=[]
        for x in range(SCREEN_WIDTH):
            for y in range(SCREEN_HEIGHT):
                if (x-a)**2 + (y-b)**2 == r**2:
                    for i in range(-street_width // 2, street_width // 2):
                        for j in range(-street_width // 2, street_width // 2):
                            if 0 <= x + i < SCREEN_WIDTH and 0 <= y + j < SCREEN_HEIGHT:
                                if screen[y+j][x+i] == 1:
                                    screen[y+j][x+i] = 4
                                    x_lst.append(x+i)
                                    y_lst.append(y+j)
        display_screen(screen)
        if len(x_lst)==0 or len(y_lst)==0:
            return -1
        return [statistics.mean(x_lst),statistics.mean(y_lst)]

# %%
building=Building(street, screen)
print(building.size)
building.point
# Out:
# * 17.517821025563997   [200, 200]
# wid 17.517821025563997
# [24.74151589912577, 17.517821025563997, 17.40297568368916]
# [203.93957703927492, 213.5619335347432]

# %%
street = draw_street(screen, points, STREET_WIDTH)

# %%
def find_point( screen, width, point):
    a = point[0]
    b = point[1]
    r = width
    street_width=15
    x_lst=[]
    y_lst=[]
    for x in range(SCREEN_WIDTH):
        for y in range(SCREEN_HEIGHT):
            if (x-a)**2 + (y-b)**2 == r**2:
                for i in range(-street_width // 2, street_width // 2):
                    for j in range(-street_width // 2, street_width // 2):
                        if 0 <= x + i < SCREEN_WIDTH and 0 <= y + j < SCREEN_HEIGHT:
                            if screen[y+j][x+i] == 1:
                                print(x+i," ,",y+j)
                                screen[y+j][x+i] = 4
                                x_lst.append(x+i)
                                y_lst.append(y+j)
    if len(x_lst)==0 or len(y_lst)==0:
        return -1
    return [statistics.mean(x_lst),statistics.mean(y_lst)]

mean=find_point(screen, 130, [street.points[0][0],street.points[0][1]])
display_screen(screen)
mean
# Out:
# 237  , 318
# 237  , 319
# 238  , 318
# 238  , 319
# 238  , 320
# 238  , 321
# 238  , 322
# 242  , 312
# 242  , 313
# 242  , 314
# 242  , 315
# 242  , 316
# 242  , 317
# 242  , 318
# 242  , 319
# 242  , 320
# 242  , 321
# 242  , 322
# 242  , 323
# 242  , 324
# 242  , 325
# 242  , 326
# 243  , 312
# 243  , 313
# 243  , 314
# 243  , 315
# 243  , 316
# 243  , 317
# 243  , 318
# 243  , 319
# 243  , 320
# 243  , 321
# 243  , 322
# 243  , 323
# 243  , 324
# 243  , 325
# 243  , 326
# 244  , 312
# 244  , 313
# 244  , 314
# 244  , 315
# 244  , 316
# 244  , 317
# 244  , 318
# 244  , 319
# 244  , 320
# 244  , 321
# 244  , 322
# 244  , 323
# 244  , 324
# 244  , 325
# 244  , 326
# 245  , 312
# 245  , 313
# 245  , 314
# 245  , 315
# 245  , 316
# 245  , 317
# 245  , 318
# 245  , 319
# 245  , 320
# 245  , 321
# 245  , 322
# 245  , 323
# 245  , 324
# 245  , 325
# 245  , 326
# 246  , 312
# 246  , 313
# 246  , 314
# 246  , 315
# 246  , 316
# 246  , 317
# 246  , 318
# 246  , 319
# 246  , 320
# 246  , 321
# 246  , 322
# 246  , 323
# 246  , 324
# 246  , 325
# 246  , 326
# 247  , 312
# 247  , 313
# 247  , 314
# 247  , 315
# 247  , 316
# 247  , 317
# 247  , 318
# 247  , 319
# 247  , 320
# 247  , 321
# 247  , 322
# 247  , 323
# 247  , 324
# 247  , 325
# 247  , 326
# 248  , 312
# 248  , 313
# 248  , 314
# 248  , 315
# 248  , 316
# 248  , 317
# 248  , 318
# 248  , 319
# 248  , 320
# 248  , 321
# 248  , 322
# 248  , 323
# 248  , 324
# 248  , 325
# 248  , 326
# 249  , 312
# 249  , 313
# 249  , 314
# 249  , 315
# 249  , 316
# 249  , 317
# 249  , 318
# 249  , 319
# 249  , 320
# 249  , 321
# 249  , 322
# 249  , 323
# 249  , 324
# 249  , 325
# 249  , 326
# 250  , 312
# 250  , 313
# 250  , 314
# 250  , 315
# 250  , 316
# 250  , 317
# 250  , 318
# 250  , 319
# 250  , 320
# 250  , 321
# 250  , 322
# 250  , 323
# 250  , 324
# 250  , 325
# 250  , 326
# 251  , 312
# 251  , 313
# 251  , 314
# 251  , 315
# 251  , 316
# 251  , 317
# 251  , 318
# 251  , 319
# 251  , 320
# 251  , 321
# 251  , 322
# 251  , 323
# 251  , 324
# 251  , 325
# 251  , 326
# 252  , 312
# 252  , 313
# 252  , 314
# 252  , 315
# 252  , 316
# 252  , 317
# 252  , 318
# 252  , 319
# 252  , 320
# 252  , 321
# 252  , 322
# 252  , 323
# 252  , 324
# 252  , 325
# 252  , 326
# 253  , 312
# 253  , 313
# 253  , 314
# 253  , 315
# 253  , 316
# 253  , 317
# 253  , 318
# 253  , 319
# 253  , 320
# 253  , 321
# 253  , 322
# 253  , 323
# 253  , 324
# 253  , 325
# 253  , 326
# 254  , 312
# 254  , 313
# 254  , 314
# 254  , 315
# 254  , 316
# 254  , 317
# 254  , 318
# 254  , 319
# 254  , 320
# 254  , 321
# 254  , 322
# 254  , 323
# 254  , 324
# 254  , 325
# 254  , 326
# 255  , 314
# 255  , 315
# 255  , 316
# 255  , 317
# 255  , 318
# 255  , 319
# 255  , 320
# 255  , 321
# 255  , 322
# 255  , 323
# 255  , 324
# 255  , 325
# 255  , 326
# 256  , 317
# 256  , 318
# 256  , 319
# 256  , 320
# 256  , 321
# 256  , 322
# 256  , 323
# 256  , 324
# 256  , 325
# 256  , 326
# [248.44, 319.18666666666667]

# %%
class Sample:
    def __init__(self):
        self.num=5
        a=3
        self.pow=self.func(a)
        
    def func(self, num):
        return num**2
samp=Sample()

# %%
samp.pow
# Out:
# 9

# %%
import math

class Line:
    def __init__(self, a ,b):
        self.a = a
        self.b = b
        
    def find_intersection(self, line):
        x = (line.b - self.b) / (self.a - line.a)
        y = self.a * x + self.b
        return x, y

def parallel_line(p1,p2,dist):
    # the line is not function
    if p1[0] == p2[0]:
        return ([p1[0]+dist,p1[1]],[p2[0]+dist,p2[1]])
    
    slope = (p1[1]-p2[1])/(p1[0]-p2[0])
    vertical = -1/slope
    b = p1[1]-slope*p1[0]
    first_line = Line(slope, b)
    
    new_b= b+dist/(math.sin(math.atan(slope)))
    new_line = Line(slope, new_b)
    
    b_p1 = p1[1]-vertical*p1[0]
    line_for_p1 = Line(vertical, b_p1)
    
    b_p2 = p2[1]-vertical*p2[0]
    line_for_p2 = Line(vertical, b_p2)
    
    return line_for_p1.find_intersection(new_line), line_for_p2.find_intersection(new_line)

# %%
parallel_line([1,2],[2,4],6)
# Out:
# ((-1.6832815729997477, 3.341640786499874),
#  (-0.6832815729997478, 5.341640786499874))

# %%
import math

def parallel_line(p1, p2, dist):
    x1, y1 = p1
    x2, y2 = p2

    # Calculate the direction vector between p1 and p2
    dx = x2 - x1
    dy = y2 - y1

    # Calculate the length of the direction vector (distance between points)
    line_length = math.sqrt(dx**2 + dy**2)

    # Normalize the perpendicular vector (unit normal vector)
    unit_perpendicular = (-dy / line_length, dx / line_length)

    # Create the new parallel points by moving the original points
    p1_parallel = (
        x1 + dist * unit_perpendicular[0], 
        y1 + dist * unit_perpendicular[1]
    )
    p2_parallel = (
        x2 + dist * unit_perpendicular[0], 
        y2 + dist * unit_perpendicular[1]
    )

    return p1_parallel, p2_parallel

# Example usage
p1 = (1, 2)
p2 = (2, 4)
distance = 6  # Distance to the parallel line

parallel_p1, parallel_p2 = parallel_line(p1, p2, distance)
print("Parallel line points:", parallel_p1, parallel_p2)
# Out:
# Parallel line points: (-4.366563145999495, 4.683281572999748) (-3.3665631459994954, 6.683281572999748)

# %%
# Import math Library
import math

# Return the hyperbolic tangent of different numbers
print(math.tanh(45))
# Out:
# 1.0

# %%
import math

def angle_with_x_axis(x, y):
    angle_rad = math.atan(1)
    angle_deg = math.degrees(angle_rad)
    return angle_deg

# Example coordinates
x_coordinate = 4
y_coordinate = 4

# Calculate and print the angle with the x-axis
angle = angle_with_x_axis(x_coordinate, y_coordinate)
print(angle)
# Out:
# 45.0

# %%
class Line:
    def __init__(self, a, b):
        self.a = a
        self.b = b

def find_intersection(line1, line2):
    x = (line2.b - line1.b) / (line1.a - line2.a)
    y = line1.a * x + line1.b
    return x, y

# Example usage:
line1 = Line(2, 1)  # Represents the line y = 2x + 1
line2 = Line(-1, 4)  # Represents the line y = -x + 4

intersection_point = find_intersection(line1, line2)
print(intersection_point)
# Out:
# (1.0, 3.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Function to calculate parallel line points
def parallel_line(p1, p2, dist):
    x1, y1 = p1
    x2, y2 = p2

    # Calculate the direction vector between p1 and p2
    dx = x2 - x1
    dy = y2 - y1

    # Calculate the length of the direction vector (distance between points)
    line_length = math.sqrt(dx**2 + dy**2)

    # Normalize the perpendicular vector (unit normal vector)
    unit_perpendicular = (-dy / line_length, dx / line_length)

    # Create the new parallel points by moving the original points
    p1_parallel = (
        x1 + dist * unit_perpendicular[0], 
        y1 + dist * unit_perpendicular[1]
    )
    p2_parallel = (
        x2 + dist * unit_perpendicular[0], 
        y2 + dist * unit_perpendicular[1]
    )

    return p1_parallel, p2_parallel

# Example points and distance
p1 = (1, 2)
p2 = (2, 4)
distance = 2  # Distance to the parallel line

# Get the parallel line points
parallel_p1, parallel_p2 = parallel_line(p1, p2, distance)

# Plotting the original and parallel lines
plt.figure(figsize=(6,6))

# Original line
x_values = [p1[0], p2[0]]
y_values = [p1[1], p2[1]]
plt.plot(x_values, y_values, label="Original Line", color='blue')

# Parallel line
parallel_x_values = [parallel_p1[0], parallel_p2[0]]
parallel_y_values = [parallel_p1[1], parallel_p2[1]]
plt.plot(parallel_x_values, parallel_y_values, label="Parallel Line", color='red')

# Marking the points
plt.scatter([p1[0], p2[0]], [p1[1], p2[1]], color='blue', zorder=5)
plt.scatter([parallel_p1[0], parallel_p2[0]], [parallel_p1[1], parallel_p2[1]], color='red', zorder=5)

# Labels and title
plt.legend()
plt.title("Original Line and Parallel Line")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

class Line:
    def __init__(self, a, b):
        self.a = a  # slope of the line
        self.b = b  # y-intercept of the line

    def find_intersection(self, line):
        # Check if the lines are parallel
        if self.a == line.a:
            return None  # No intersection (parallel lines)

        x = (line.b - self.b) / (self.a - line.a)
        y = self.a * x + self.b
        return x, y

def parallel_line(p1, p2, dist):
    # Special case for vertical lines
    if p1[0] == p2[0]:
        return ([p1[0] + dist, p1[1]], [p2[0] + dist, p2[1]])

    # Slope of the original line
    slope = (p1[1] - p2[1]) / (p1[0] - p2[0])
    # Slope of the perpendicular line
    vertical_slope = -1 / slope

    # Y-intercept of the original line
    b = p1[1] - slope * p1[0]
    first_line = Line(slope, b)

    # Calculate new parallel line's y-intercept
    new_b = b + dist / math.sin(math.atan(slope))
    new_line = Line(slope, new_b)

    # Find intersections for p1 and p2 with perpendicular lines
    b_p1 = p1[1] - vertical_slope * p1[0]
    line_for_p1 = Line(vertical_slope, b_p1)

    b_p2 = p2[1] - vertical_slope * p2[0]
    line_for_p2 = Line(vertical_slope, b_p2)

    # Return the intersections (the parallel points)
    return line_for_p1.find_intersection(new_line), line_for_p2.find_intersection(new_line)

# Example points and distance
p1 = (1, 2)
p2 = (2, 4)
distance = 2  # Distance to the parallel line

# Get the parallel line points
parallel_p1, parallel_p2 = parallel_line(p1, p2, distance)

# Plotting the original and parallel lines
plt.figure(figsize=(6,6))

# Original line
x_values = [p1[0], p2[0]]
y_values = [p1[1], p2[1]]
plt.plot(x_values, y_values, label="Original Line", color='blue')

# Parallel line
parallel_x_values = [parallel_p1[0], parallel_p2[0]]
parallel_y_values = [parallel_p1[1], parallel_p2[1]]
plt.plot(parallel_x_values, parallel_y_values, label="Parallel Line", color='red')

# Marking the points
plt.scatter([p1[0], p2[0]], [p1[1], p2[1]], color='blue', zorder=5)
plt.scatter([parallel_p1[0], parallel_p2[0]], [parallel_p1[1], parallel_p2[1]], color='red', zorder=5)

# Labels and title
plt.legend()
plt.title("Original Line and Parallel Line")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)

# Show plot
plt.show()
